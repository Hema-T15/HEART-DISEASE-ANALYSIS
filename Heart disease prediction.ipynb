# %% [markdown]
# HEART DISEASE ANALYSIS

# %% [markdown]
# IMPORTING LIBRARIES

# %% [markdown]
# This project involves analyzing a heart disease dataset using core Python libraries to uncover meaningful patterns and insights. Using Pandas for data handling and Matplotlib/Seaborn for data visualization, I performed thorough exploratory data analysis (EDA) to understand how various factors such as age, gender, cholesterol levels, chest pain types, and blood pressure relate to heart disease.

# %%
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib.pyplot
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001412467E690>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplotlib-pyplot/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000014120B142C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplotlib-pyplot/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000141246F85C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplotlib-pyplot/
# ...

# %%
import pandas as pd

# %% [markdown]
# IMPORTING THE DATA

# %% [markdown]
# INFORMATION OF THE DATA

# %%
df=pd.read_csv("medicaldata.csv")
df
# Out:
#       Age Gender  Heart rate  Systolic blood pressure  \
# 0      64   Male          66                      160
# 1      21   Male          94                       98
# 2      55   Male          64                      160
# 3      64   Male          70                      120
# 4      55   Male          64                      112
# ...   ...    ...         ...                      ...
# 1314   44   Male          94                      122
# 1315   66   Male          84                      125
# 1316   45   Male          85                      168
# 1317   54   Male          58                      117
# 1318   51   Male          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   object
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 92.9+ KB

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %%
df.head(4)
# Out:
#    Age Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64   Male          66                      160                        83
# 1   21   Male          94                       98                        46
# 2   55   Male          64                      160                        77
# 3   64   Male          70                      120                        55
#
#    Blood sugar  CK-MB  Troponin    Result
# 0        160.0   1.80     0.012  negative
# 1        296.0   6.75     1.060  positive
# 2        270.0   1.99     0.003  negative
# 3        270.0  13.87     0.122  positive

# %%
df.tail(4)
# Out:
#       Age Gender  Heart rate  Systolic blood pressure  \
# 1315   66   Male          84                      125
# 1316   45   Male          85                      168
# 1317   54   Male          58                      117
# 1318   51   Male          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 1315                        55        149.0   1.33     0.172  positive
# 1316                       104         96.0   1.24     4.250  positive
# 1317                        68        443.0   5.80     0.359  positive
# 1318                        79        134.0  50.89     1.770  positive

# %%
df["Blood sugar"].max()
# Out:
# 541.0

# %%
df["Systolic blood pressure"].max()
# Out:
# 223

# %%
df["Diastolic blood pressure"].max()
# Out:
# 154

# %%
df["Heart rate"].max()
# Out:
# 1111

# %%
print(df.shape)
for col in df.columns:
    print(f"{col} : {df[col].nunique()}")
# Out:
# (1319, 9)
# Age : 75
# Gender : 2
# Heart rate : 79
# Systolic blood pressure : 116
# Diastolic blood pressure : 73
# Blood sugar : 244
# CK-MB : 700
# Troponin : 352
# Result : 2

# %% [markdown]
# FINDING THE MISSING VALUES

# %%
import missingno as msn

# %%
df.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %% [markdown]
# FORTUNATELY THERE IS NO NULL OR MISSING VALUES WE CAN GO FOR VISUALISATIONS

# %% [markdown]
# IMPORTING VISUALIZATION FRAMEWORKS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
des=sns.color_palette("blend:blue,black",as_cmap=True)
df.describe().style.background_gradient(cmap=des,axis=None)
# Out:
# <style type="text/css">
# #T_ce556_row0_col0, #T_ce556_row0_col1, #T_ce556_row0_col2, #T_ce556_row0_col3, #T_ce556_row0_col4, #T_ce556_row0_col5, #T_ce556_row0_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col0, #T_ce556_row2_col1 {
#   background-color: #0000f5;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col1, #T_ce556_row6_col3 {
#   background-color: #0000f0;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col2, #T_ce556_row5_col2 {
#   background-color: #0000e7;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col3, #T_ce556_row2_col4, #T_ce556_row5_col1 {
#   background-color: #0000f1;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col4 {
#   background-color: #0000e3;
#   color: #f1f1f1;
# }
# #T_ce556_row1_col5, #T_ce556_row2_col0, #T_ce556_row2_col3, #T_ce556_row3_col0 {
#   background-color: #0000fd;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# GROUPING OF DATA

# %%
grouped = df.groupby('Result').mean(numeric_only=True)
print(grouped.T)
# Out:
# Result                      negative    positive
# Age                        52.094303   58.766667
# Heart rate                 77.886051   78.619753
# Systolic blood pressure   127.856582  126.739506
# Diastolic blood pressure   72.440079   72.161728
# Blood sugar               149.757760  144.671605
# CK-MB                       2.555344   23.266838
# Troponin                    0.026988    0.570798

# %% [markdown]
# PLOTTING
# 1) HEART DISEASE BY AGE
# 2)SYSTOLIC BLOOD PRESSURE
# 3)CK-MB VS HEART DISEASE
# 4)TROPONIN VS HEART DISEASE
# USING BOXPLOT

# %%
sns.boxplot(x="Result", y="Age", data=df,color="blue")
plt.title("Age Distribution by Heart Disease Result")
plt.show()

sns.boxplot(x="Result", y="Systolic blood pressure", data=df,color="red")
plt.title("Systolic BP vs Heart Disease")
plt.show()

sns.boxplot(x="Result", y="CK-MB", data=df,color="pink")
plt.title("CK-MB vs Heart Disease")
plt.show()

sns.boxplot(x="Result", y="Troponin", data=df,color="beige")
plt.title("Troponin vs Heart Disease")
plt.show()

# %% [markdown]
# DEMOGRAPHIC DISTRIBUTION ANALYSIS

# %%
numeric_features = ["Age", "Heart rate", "Systolic blood pressure", "Diastolic blood pressure", 
                    "Blood sugar", "CK-MB", "Troponin", "Result"]

plt.figure(figsize=(12, 8))
for i, feature in enumerate(numeric_features):
    plt.subplot(3, 3, i+1)
    sns.histplot(df[feature], kde=True)
    plt.title(f"Distribution of {feature}")
plt.tight_layout()
plt.show()

# %% [markdown]
# FEATURE INTERACTION

# %%
sns.pairplot(df, hue="Result", diag_kind="kde")
plt.show()

# %%
sns.countplot(data=df, x='Result')
plt.title("Target Distribution")
plt.show()

sns.boxplot(x='Result', y='Age', data=df)
plt.title("Age vs Result")
plt.show()

# %% [markdown]
# DETERMINING RELATIONSHIP BETWEEN DIFFERENT FEATURES

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# IDENTIFYING THE MOST AFFECTED GROUP ACCORDING TO GENDER AND AGE

# %%
age_bins = [0, 20, 40, 60, 80, 100]
age_labels = ["0-20", "21-40", "41-60", "61-80", "81-100"]

df["Age_group"] = pd.cut(df["Age"], bins=age_bins, labels=age_labels, right=False)

dd = df.groupby(["Result", "Gender", "Age_group"], observed=True).size()

print(dd)
# Out:
# Result    Gender  Age_group
# negative  Female  0-20           1
#                   21-40         34
#                   41-60         81
#                   61-80         82
#                   81-100         4
#           Male    0-20           1
#                   21-40         57
#                   41-60        152
#                   61-80         93
#                   81-100         4
# positive  Female  0-20           2
#                   21-40         12
#                   41-60         85
#                   61-80        133
#                   81-100        13
#           Male    21-40         45
#                   41-60        229
#                   61-80        273
#                   81-100        15
# dtype: int64

# %%
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# Filter data for positive heart disease cases
df_filtered = df[df["Result"] == "positive"]

# Group by Age and Gender, counting occurrences
df_grouped = df_filtered.groupby(["Age_group", "Gender"], observed=True)["Result"].count().reset_index()

# Create a bar plot to visualize the distribution
plt.figure(figsize=(10, 6))
sns.barplot(data=df_grouped, x="Age_group", y="Result", hue="Gender", palette="Paired")


plt.title("Heart Disease Cases Across Age Groups and Gender")
plt.xlabel("Age Group")
plt.ylabel("Count of Positive Cases")
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# Key findings were visualized through histograms, box plots, heatmaps, and correlation matrices, allowing clear interpretation of trends and risk factors. The project emphasized data cleaning, handling missing values, and interpreting relationships between features.
#
# This analysis helps highlight the power of Python in deriving insights from healthcare data and supports better understanding of heart disease indicators.
#
# Tools Used: Python, Jupyter Notebook, Pandas, Seaborn, Matplotlib
